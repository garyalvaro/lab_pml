# %% [markdown]
# <b>Pertemuan 9 Lab PML</b> <br>
#
# &#169; Gary Alvaro

# %% [markdown]
# # Deployment
#
# Langkah awal yang harus dilakukan adalah mempersiapkan data latih dan data uji (di luar sistem).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
filename = "../Pertemuan 4 - Preprocessing NLP/DatasetReviewProduk-LabPML.csv"

data = pd.read_csv(filename)
data
# Out:
#                                                    teks  akurasi  kualitas  \
# 0     Senternya kecil, tapi terangnya luar biasa, uk...        0         1
# 1     Sempat konfirmasi ke penjual tapi tidak member...        0         0
# 2     mantap Namun akan lebih baik apabila baterainy...        1         0
# 3                Kualitas jelek, wajar aja harga murah,        0         1
# 4     Pelayanan buruk klo kata tidak aktif bertanya ...        1         0
# ...                                                 ...      ...       ...
# 1495  Respon lambat, lambat sampai masa ampe 8 hari,...        0         1
# 1496                                    Sesuai pesanan.        1         0
# 1497  Tempat utk cash susah dibuka sampai hrs dtg ke...        0         1
# 1498  Barang masi rapi, di segel.. Suara full bass.....        0         1
# 1499  barang sesuai pesanan... respon cepat n ramah....        1         0
#
# ...

# %%
data_training, data_testing = train_test_split(data, test_size=0.2, random_state=42, shuffle=True)

# %%
data_training.to_csv('datax_training.csv', index=False)
data_testing.to_csv('datax_testing.csv', index=False)
